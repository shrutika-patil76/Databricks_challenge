# %%
spark.table("ecommerce.events_delta").display()

# %%
# %sql
DESCRIBE HISTORY ecommerce.events_delta;

# %%
spark.table("ecommerce.events_delta").printSchema()

# %%
from pyspark.sql.types import StructType, StructField, TimestampType, StringType, IntegerType, LongType, DoubleType
from datetime import datetime

# Define schema exactly same as table
schema = StructType([
    StructField("event_time", TimestampType(), True),
    StructField("event_type", StringType(), True),
    StructField("product_id", IntegerType(), True),
    StructField("category_id", LongType(), True),
    StructField("category_code", StringType(), True),
    StructField("brand", StringType(), True),
    StructField("price", DoubleType(), True),
    StructField("user_id", IntegerType(), True),
    StructField("user_session", StringType(), True)
])

# Create new records with correct datatypes
new_data = [
    (datetime(2026, 3, 2, 10, 0, 0), "purchase", 9991, 111, "electronics.smartphone", "TestBrand", 19999.0, 99901, "session_1"),
    (datetime(2026, 3, 2, 10, 5, 0), "view", 9992, 112, "electronics.laptop", "TestBrand", 55999.0, 99902, "session_2")
]

new_df = spark.createDataFrame(new_data, schema)

# Append to delta table
new_df.write.format("delta") \
    .mode("append") \
    .saveAsTable("ecommerce.events_delta")

# %%
# %sql
DESCRIBE HISTORY ecommerce.events_delta;

# %%
# %sql
SELECT * 
FROM ecommerce.events_delta
VERSION AS OF 8;

# %%
# %sql
SELECT * FROM ecommerce.events_delta
EXCEPT
SELECT * FROM ecommerce.events_delta VERSION AS OF 7;

# %%
# %sql
RESTORE TABLE ecommerce.events_delta TO VERSION AS OF 8;
